# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns


tips = pd.read_csv("C:\\Users\\RICHA\\Desktop\\gender_age.csv")

# %%
ax = sns.violinplot(x=tips["Age Bracket"], inner="box")

# %%
ax = sns.violinplot(x=tips["Age Bracket"], inner="quartile")

# %%
ax = sns.violinplot(x="Current Status", y="Age Bracket", data=tips, scale="area")

# %%
ax = sns.violinplot(x="Gender", y="Age Bracket", data=tips, scale="area")

# %%
import scipy.stats as stats

# %%
stats.norm.cdf(20,tips["Age Bracket"].mean(),tips["Age Bracket"].std())
# Out:
# 0.13417257722623416

# %%
stats.norm.cdf(102,tips["Age Bracket"].mean(),tips["Age Bracket"].std())
# Out:
# 0.9998106953452357

# %%
stats.norm.ppf(0.13,tips["Age Bracket"].mean(),tips["Age Bracket"].std())
# Out:
# 19.656804266691474

# %%
stats.norm.ppf(0.999,tips["Age Bracket"].mean(),tips["Age Bracket"].std())
# Out:
# 93.83192270688465

# %%
stats.norm.pdf(102,tips["Age Bracket"].mean(),tips["Age Bracket"].std())
# Out:
# 4.092424262811193e-05

# %%
stats.norm.rvs(9131,tips["Age Bracket"].mean(),tips["Age Bracket"].std())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d13a5de8c814> in <module>
# ----> 1 stats.norm.rvs(9131,tips["Age Bracket"].mean(),tips["Age Bracket"].std())
#
# ~\anaconda3\envs\datascience\lib\site-packages\scipy\stats\_distn_infrastructure.py in rvs(self, *args, **kwds)
#    1002             vals = self._rvs(*args)
#    1003         else:
# -> 1004             vals = self._rvs(*args, size=size, random_state=random_state)
#    1005
#    1006         vals = vals * scale + loc
#
# ~\anaconda3\envs\datascience\lib\site-packages\scipy\stats\_continuous_distns.py in _rvs(self, size, random_state)
#     296     """
#     297     def _rvs(self, size=None, random_state=None):
# --> 298         return random_state.standard_normal(size)
#     299
#     300     def _pdf(self, x):
#
# mtrand.pyx in numpy.random.mtrand.RandomState.standard_normal()
#
# ...
